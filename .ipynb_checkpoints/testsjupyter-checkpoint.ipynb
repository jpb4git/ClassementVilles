# %%
from apps.cities import tools

data = tools.readData()
data.head(10)
# Out:
#    0   1                      2                      3   \
# 0   1  01                   ozan                   OZAN
# 1   2  01  cormoranche-sur-saone  CORMORANCHE-SUR-SAONE
# 2   3  01              plagne-01                 PLAGNE
# 3   4  01                tossiat                TOSSIAT
# 4   5  01               pouillat               POUILLAT
# 5   6  01                torcieu                TORCIEU
# 6   7  01              replonges              REPLONGES
# 7   8  01              corcelles              CORCELLES
# 8   9  01                  peron                  PERON
# 9  10  01               relevant               RELEVANT
#
#                       4                      5          6           7      8   \
# 0                   ozan                   Ozan       O250         OSN  01190
# 1  cormoranche sur saone  Cormoranche-sur-Saône  C65652625  KRMRNXSRSN  01290
# 2                 plagne                 Plagne       P425        PLKN  01130
# ...

# %%
sortedData = tools.sortData(data)
sortedData.head(10)
# Out:
#           0   1            2            3            4            5        6   \
# 30437  30438  75        paris        PARIS        paris        Paris     P620
# 4439    4440  13    marseille    MARSEILLE    marseille    Marseille     M624
# 28152  28153  69         lyon         LYON         lyon         Lyon     L500
# 11718  11719  31     toulouse     TOULOUSE     toulouse     Toulouse     T420
# 2049    2050  06         nice         NICE         nice         Nice     N200
# 16755  16756  44       nantes       NANTES       nantes       Nantes     N320
# 27303  27304  67   strasbourg   STRASBOURG   strasbourg   Strasbourg  S362162
# 13338  13339  34  montpellier  MONTPELLIER  montpellier  Montpellier    M3146
# 12678  12679  33     bordeaux     BORDEAUX     bordeaux     Bordeaux     B632
# 13467  13468  35       rennes       RENNES       rennes       Rennes     R520
#
#             7                                                  8    9   ...  \
# ...

# %%
barData = tools.createGraph(sortedData)
